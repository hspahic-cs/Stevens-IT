# %%
import pandas as pd 

# Reading Data
df = pd.read_csv("seasonal_data.csv")

# Cleaning Data and converting to % of total sales
def clean_data(row):
    total = int(row['Total'].replace(',', ''))
    for col in row.index:
        if col not in ['Total', 'Year']:
            value = row[col].replace(",", '')
            row[col] = int(value) / total

    return row

df = df.apply(clean_data, axis=1)
df.head(10)
# Out:
#    Year       Jan       Feb       Mar       Apr       May       Jun       Jul  \
# 0  2022  0.072329  0.071531  0.084187  0.084188  0.087073  0.085935  0.084932
# 1  2021  0.070067  0.066446  0.085208  0.084677  0.086869  0.085822  0.085631
# 2  2020  0.077264  0.077063  0.076533  0.065605  0.081306  0.085772  0.088370
# 3  2019  0.073798  0.071462  0.083017  0.081877  0.087936  0.083267  0.085472
# 4  2018  0.074258  0.072771  0.084975  0.080293  0.088280  0.084774  0.084413
# 5  2017  0.073617  0.072982  0.084279  0.081257  0.086283  0.084033  0.082921
# 6  2016  0.072979  0.075376  0.083703  0.081931  0.085380  0.084407  0.083917
# 7  2015  0.074464  0.072630  0.083433  0.082201  0.086916  0.084102  0.085934
# 8  2014  0.073487  0.072907  0.082988  0.082710  0.088042  0.083066  0.084988
# 9  2013  0.075057  0.074755  0.084300  0.081663  0.087389  0.082911  0.084450
#
#         Aug       Sep       Oct       Nov       Dec      Total
# 0  0.086586  0.081870  0.084649  0.084846  0.091875  8,070,945
# 1  0.085041  0.081707  0.085500  0.087697  0.095336  7,366,214
# 2  0.087854  0.085464  0.089041  0.087481  0.098246  6,223,300
# 3  0.087674  0.079750  0.084507  0.086146  0.095094  6,169,122
# 4  0.086978  0.079705  0.084106  0.086565  0.092883  5,983,129
# 5  0.085526  0.081927  0.083028  0.086809  0.097338  5,732,863
# 6  0.085677  0.081468  0.082308  0.084859  0.097994  5,506,177
# 7  0.085630  0.080887  0.083478  0.083406  0.096919  5,350,925
# 8  0.086552  0.080796  0.084069  0.084182  0.096212  5,217,688
# 9  0.086982  0.079226  0.083128  0.084753  0.095387  5,002,918

# %%
# Prilitary Data Analysis
df.describe()
# Out:
#               Year        Jan        Feb        Mar        Apr        May  \
# count    31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean   2007.000000   0.073285   0.072939   0.082861   0.081335   0.086249
# std       9.092121   0.001906   0.002352   0.002036   0.003112   0.001691
# min    1992.000000   0.069242   0.066446   0.076533   0.065605   0.081306
# 25%    1999.500000   0.072122   0.071621   0.082134   0.081248   0.085349
# 50%    2007.000000   0.073487   0.072907   0.083006   0.081663   0.086297
# 75%    2014.500000   0.074194   0.073546   0.084275   0.082199   0.087114
# max    2022.000000   0.078022   0.078307   0.085809   0.084677   0.090618
#
#              Jun        Jul        Aug        Sep        Oct        Nov  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000  31.000000
# mean    0.084514   0.084643   0.086450   0.081067   0.083865   0.084873
# std     0.001053   0.001392   0.001113   0.001466   0.001746   0.002019
# min     0.082911   0.082054   0.084285   0.077517   0.079663   0.076406
# 25%     0.083521   0.083818   0.085653   0.079885   0.082962   0.084127
# 50%     0.084522   0.084625   0.086591   0.081355   0.083478   0.085079
# 75%     0.085460   0.085440   0.087209   0.081801   0.084911   0.086078
# max     0.086445   0.088370   0.088826   0.085464   0.089041   0.087697
#
#              Dec
# count  31.000000
# mean    0.097920
# std     0.003535
# min     0.087494
# 25%     0.096091
# 50%     0.097994
# 75%     0.099500
# max     0.104287

# %%
import matplotlib.pyplot as plt

# Extracting data to plot
data = df.values.tolist()
trimmed_data = [sublist[1:-1] for sublist in data]
y = [data_point for sublist in trimmed_data for data_point in sublist]

y.reverse()
x = [i for i in range(len(y))]

# Plotting data# Visual Inspection: Plotting the Time Series
plt.figure(figsize=(10, 6))
plt.plot()
plt.title('Time Series')
plt.show()
plt.figure(figsize=(20, 20))
plt.plot(x, y)

plt.title("Seasonal Sales of Retail & Food Services by Month (1992-2022)", fontsize=20)
plt.xlabel("Date", fontsize=10)
plt.ylabel("Percent of Total Sales of Yearly Sales", fontsize=10)

plt.grid(True)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import statsmodels.graphics.tsaplots as sgt

# Plotting Autocorrelation
plt.figure(figsize=(12, 5))

# %%
# Rolling Statistics
rolling_means = {}
rolling_stds = {}

for month in df.columns:
    if(month not in['Year', 'Total']):
        print(month)
        rolling_means[month] = df[month].rolling(window=12).mean()
        rolling_stds[month] = df[month].rolling(window=12).std()


rolling_means

# plt.figure(figsize=(10, 6))
# plt.plot(data, color='blue', label='Original')
# plt.plot(rolling_mean, color='red', label='Rolling Mean')
# plt.plot(rolling_std, color='black', label='Rolling Std Dev')
# plt.legend()
# plt.title('Rolling Mean & Standard Deviation')
# plt.show()

# # Augmented Dickey-Fuller Test
# adf_test = adfuller(data, autolag='AIC')
# print(f'ADF Statistic: {adf_test[0]}')
# print(f'p-value: {adf_test[1]}')

# # KPSS Test
# kpss_test = kpss(data, regression='c')
# print(f'KPSS Statistic: {kpss_test[0]}')
# print(f'p-value: {kpss_test[1]}')
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
# Sep
# Oct
# Nov
# Dec
# Total
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:368, in BaseWindow._prep_values(self, values)
#     367     else:
# --> 368         values = ensure_float64(values)
#     369 except (ValueError, TypeError) as err:
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: '8,070,945'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:448, in BaseWindow._apply_series(self, homogeneous_func, name)
#     447 try:
# --> 448     values = self._prep_values(obj._values)
#     449 except (TypeError, NotImplementedError) as err:
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:370, in BaseWindow._prep_values(self, values)
#     369 except (ValueError, TypeError) as err:
# --> 370     raise TypeError(f"cannot handle this type -> {values.dtype}") from err
#     372 # Convert inf to nan for C funcs
#
# TypeError: cannot handle this type -> object
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# /home/harris/University/MA-641/final-project.ipynb Cell 5 line 8
#       <a href='vscode-notebook-cell:/home/harris/University/MA-641/final-project.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     if(month != ('Year' or 'Total')):
#       <a href='vscode-notebook-cell:/home/harris/University/MA-641/final-project.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>         print(month)
# ----> <a href='vscode-notebook-cell:/home/harris/University/MA-641/final-project.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>         rolling_means[month] = df[month].rolling(window=12).mean()
#       <a href='vscode-notebook-cell:/home/harris/University/MA-641/final-project.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>         rolling_stds[month] = df[month].rolling(window=12).std()
#      <a href='vscode-notebook-cell:/home/harris/University/MA-641/final-project.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> rolling_means
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:2111, in Rolling.mean(self, numeric_only, engine, engine_kwargs)
#    2068 @doc(
#    2069     template_header,
#    2070     create_section_header("Parameters"),
#    (...)
#    2109     engine_kwargs: dict[str, bool] | None = None,
#    2110 ):
# -> 2111     return super().mean(
#    2112         numeric_only=numeric_only,
#    2113         engine=engine,
#    2114         engine_kwargs=engine_kwargs,
#    2115     )
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:1507, in RollingAndExpandingMixin.mean(self, numeric_only, engine, engine_kwargs)
#    1505         return self._numba_apply(sliding_mean, engine_kwargs)
#    1506 window_func = window_aggregations.roll_mean
# -> 1507 return self._apply(window_func, name="mean", numeric_only=numeric_only)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:615, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     612     return result
#     614 if self.method == "single":
# --> 615     return self._apply_blockwise(homogeneous_func, name, numeric_only)
#     616 else:
#     617     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:468, in BaseWindow._apply_blockwise(self, homogeneous_func, name, numeric_only)
#     466 self._validate_numeric_only(name, numeric_only)
#     467 if self._selected_obj.ndim == 1:
# --> 468     return self._apply_series(homogeneous_func, name)
#     470 obj = self._create_data(self._selected_obj, numeric_only)
#     471 if name == "count":
#     472     # GH 12541: Special case for count where we support date-like types
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/window/rolling.py:450, in BaseWindow._apply_series(self, homogeneous_func, name)
#     448     values = self._prep_values(obj._values)
#     449 except (TypeError, NotImplementedError) as err:
# --> 450     raise DataError("No numeric types to aggregate") from err
#     452 result = homogeneous_func(values)
#     453 index = self._slice_axis_for_step(obj.index, result)
#
# DataError: No numeric types to aggregate
